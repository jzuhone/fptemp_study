# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from Ska.Matplotlib import cxctime2plotdate
from matplotlib.collections import LineCollection

# %%
f = h5py.File("acisfp_model_orbit_1.h5", "r")

# %%
norm = plt.Normalize(45.0, 180.0)
[np.column_stack([x, y]) for y in ys]

# %%
fig, ax = plt.subplots(figsize=(10,10))
for obs in f:
    g = f[obs]
    x = []
    y = []
    for i in range(g['fptemp'].shape[0]):
        x.append(cxctime2plotdate(g['times'][i]))
        y.append(g['fptemp'][i])
    #ax.plot_date(pdtimes, g['fptemp'][i], '-')
lc = LineCollection()
        #plot_cxctime(g['times'][i], g['fptemp'][i], ax=ax, fig=fig)
#plt.ylim(-120, -109)

# %%
f.close()
